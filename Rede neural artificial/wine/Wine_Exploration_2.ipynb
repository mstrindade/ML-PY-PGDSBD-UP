# %%
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.model_selection import train_test_split
import numpy as np
import time

# %%
r = pd.read_csv('winequality-red.csv', sep = ';')
w = pd.read_csv('winequality-white.csv', sep = ';')

# %%
r.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
w.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
set(r.quality), set(w.quality)
# Out:
# ({3, 4, 5, 6, 7, 8}, {3, 4, 5, 6, 7, 8, 9})

# %%
rw = r.copy()
rw['type'] = 1
ww = w.copy()
ww['type'] = 0
wines = rw.append(ww)
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  type
# 0         9.4        5     1
# 1         9.8        5     1
# 2         9.8        5     1
# 3         9.8        6     1
# 4         9.4        5     1
# ...       ...      ...   ...
# 4893     11.2        6     0
# 4894      9.6        5     0
# 4895      9.4        6     0
# 4896     12.8        7     0
# 4897     11.8        6     0
#
# [6497 rows x 13 columns]

# %%
r.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
w.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
plt.scatter(w['fixed acidity'], w['citric acid'])

# %%
plt.scatter(w['residual sugar'], w['chlorides'])

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (1, 12)),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dense(256, activation = 'sigmoid'),
    keras.layers.Dense(128, activation = 'relu'),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(32, activation = 'relu'),
    keras.layers.Dense(2, activation = 'softmax')
])

# %%
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',  #[0,1,2] = labels
              metrics = ['accuracy'])

# %%
wines.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')

# %%
features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
category = ['type']

# %%
X_train, X_test, y_train, y_test = train_test_split(wines[features],
                                                    wines[category],
                                                    test_size=0.25, random_state = 1) # 70% training and 30% test

# %%
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 275             7.9             0.545         0.06            4.00      0.087
# 1807            8.8             0.200         0.43           15.00      0.053
# 1564            9.1             0.280         0.49            2.00      0.059
# 3024            7.0             0.130         0.37           12.85      0.042
# 928             6.5             0.250         0.35           12.00      0.055
# ...             ...               ...          ...             ...        ...
# 905             9.2             0.580         0.20            3.00      0.081
# 3593            5.6             0.280         0.28            4.20      0.044
# 2381            7.0             0.230         0.42            5.10      0.042
# 235             7.2             0.630         0.00            1.90      0.097
# 3558            5.7             0.220         0.22           16.65      0.044
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 275                  27.0                  61.0  0.99650  3.36       0.67
# 1807                 60.0                 184.0  1.00080  3.28       0.79
# 1564                 10.0                 112.0  0.99580  3.15       0.46
# 3024                 36.0                 105.0  0.99581  3.05       0.55
# 928                  47.0                 179.0  0.99800  3.58       0.47
# ...                   ...                   ...      ...   ...        ...
# 905                  15.0                 115.0  0.99800  3.23       0.59
# 3593                 52.0                 158.0  0.99200  3.35       0.44
# 2381                 37.0                 144.0  0.99518  3.50       0.59
# 235                  14.0                  38.0  0.99675  3.37       0.58
# 3558                 39.0                 110.0  0.99855  3.24       0.48
#
#       alcohol  quality
# 275      10.7        6
# 1807      8.8        6
# 1564     10.1        5
# 3024     10.7        6
# 928      10.0        5
# ...       ...      ...
# 905       9.5        5
# 3593     10.7        7
# 2381     10.2        6
# 235       9.0        6
# 3558      9.0        6
#
# [4872 rows x 12 columns]

# %%
y_train
# Out:
#       type
# 275      1
# 1807     0
# 1564     0
# 3024     0
# 928      0
# ...    ...
# 905      1
# 3593     0
# 2381     0
# 235      1
# 3558     0
#
# [4872 rows x 1 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(list(set(y_train['type'])))
# Out:
# LabelEncoder()

# %%
y = le.transform(y_train['type'])
y
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
catega = list(set(y_train['type']))
catega
# Out:
# [0, 1]

# %%
categaf = le.transform(catega)
categaf
# Out:
# array([0, 1])

# %%
ycheck = le.inverse_transform(categaf)
ycheck
# Out:
# array([0, 1])

# %%
lista = []
X = X_train.reset_index(drop = True)
lenx = len(X)
for i in range(len(X)):
    lista.append(np.array(X[i:i+1].values))
    time.sleep(0.0001)
    print('Faltam '+str(lenx-i)+' execuções', end='  \r')
lista = np.array(lista)
lista.shape
# Out:
# Faltam 4399 execuções
# Faltam 1 execuções
# (4872, 1, 12)

# %%
lista
# Out:
# array([[[ 7.9  ,  0.545,  0.06 , ...,  0.67 , 10.7  ,  6.   ]],
#
#        [[ 8.8  ,  0.2  ,  0.43 , ...,  0.79 ,  8.8  ,  6.   ]],
#
#        [[ 9.1  ,  0.28 ,  0.49 , ...,  0.46 , 10.1  ,  5.   ]],
#
#        ...,
#
#        [[ 7.   ,  0.23 ,  0.42 , ...,  0.59 , 10.2  ,  6.   ]],
#
#        [[ 7.2  ,  0.63 ,  0.   , ...,  0.58 ,  9.   ,  6.   ]],
#
#        [[ 5.7  ,  0.22 ,  0.22 , ...,  0.48 ,  9.   ,  6.   ]]])

# %%
model.fit(lista, y, epochs = 20, batch_size = 16)
# Out:
# Epoch 1/20
# 4872/4872 [==============================] - 2s 406us/sample - loss: 0.2264 - acc: 0.9245
# Epoch 2/20
# 4872/4872 [==============================] - 2s 393us/sample - loss: 0.1920 - acc: 0.9356
# Epoch 3/20
# 4872/4872 [==============================] - 2s 331us/sample - loss: 0.1516 - acc: 0.9495
# Epoch 4/20
# 4872/4872 [==============================] - 2s 362us/sample - loss: 0.1412 - acc: 0.9516
# Epoch 5/20
# 4872/4872 [==============================] - 2s 359us/sample - loss: 0.1101 - acc: 0.9639
# Epoch 6/20
# 4872/4872 [==============================] - 1s 306us/sample - loss: 0.1077 - acc: 0.9641
# Epoch 7/20
# 4872/4872 [==============================] - 1s 293us/sample - loss: 0.1051 - acc: 0.9639
# Epoch 8/20
# 4872/4872 [==============================] - 1s 292us/sample - loss: 0.0837 - acc: 0.9733
# Epoch 9/20
# 4872/4872 [==============================] - 2s 362us/sample - loss: 0.0833 - acc: 0.9700
# Epoch 10/20
# 4872/4872 [==============================] - 2s 342us/sample - loss: 0.0781 - acc: 0.9723
# Epoch 11/20
# 4872/4872 [==============================] - 2s 348us/sample - loss: 0.0703 - acc: 0.9780
# Epoch 12/20
# 4872/4872 [==============================] - 2s 319us/sample - loss: 0.0791 - acc: 0.9739
# Epoch 13/20
# 4872/4872 [==============================] - 2s 372us/sample - loss: 0.0721 - acc: 0.9768
# Epoch 14/20
# 4872/4872 [==============================] - 2s 376us/sample - loss: 0.0624 - acc: 0.9795
# Epoch 15/20
# 4872/4872 [==============================] - 2s 329us/sample - loss: 0.0630 - acc: 0.9821
# Epoch 16/20
# 4872/4872 [==============================] - 2s 397us/sample - loss: 0.0596 - acc: 0.9811
# Epoch 17/20
# 4872/4872 [==============================] - 2s 389us/sample - loss: 0.0580 - acc: 0.9813
# Epoch 18/20
# 4872/4872 [==============================] - 2s 412us/sample - loss: 0.0585 - acc: 0.9826
# Epoch 19/20
# 4872/4872 [==============================] - 2s 404us/sample - loss: 0.0553 - acc: 0.9826
# Epoch 20/20
# 4872/4872 [==============================] - 2s 355us/sample - loss: 0.0516 - acc: 0.9850

# %%
listap = []
Xp = X_test.reset_index(drop = True)
lenxp = len(Xp)
for i in range(len(Xp)):
    listap.append(np.array(Xp[i:i+1].values))
listap = np.array(listap)
listap.shape
# Out:
# (1625, 1, 12)

# %%
yp = np.argmax(model.predict(listap), axis = 1)

# %%
yp
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
yr = np.array(y_test['type'])
yr = le.transform(yr)

# %%
yr == yp
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
sum(yr == yp)/len(yp)
# Out:
# 0.9827692307692307

# %%
result = pd.DataFrame()
result['real'] = (yr)
result['pred'] = (yp)

# %%
result.head(20)
# Out:
#     real  pred
# 0      0     0
# 1      0     0
# 2      0     0
# 3      1     1
# 4      0     1
# 5      1     1
# 6      0     0
# 7      0     0
# 8      0     0
# 9      0     0
# 10     1     1
# 11     0     0
# 12     0     0
# 13     0     0
# 14     0     0
# 15     1     1
# 16     0     0
# 17     0     0
# 18     0     0
# 19     0     0

# %%
cat = list(set(result['real']))
matrix = pd.DataFrame()
for crow in cat:
    print(crow)
    lista = []
    for ccol in cat:
        a = len(result[result['real'] == crow])
        b = len(result[(result['real'] == crow) & (result['pred'] == ccol)])
        lista.append(b/a)
    matrix[crow] = lista
# Out:
# 0
# 1

# %%
matrix = matrix.set_index(matrix.columns)

# %%
import seaborn as sns;
plt.figure(figsize=(16, 6))
sns.heatmap(matrix.T,fmt='.2f',cmap='PiYG',vmin=-1,vmax=1, annot=True, linewidths=2)
plt.xlabel('predito')
plt.ylabel('real')
# Out:
# Text(123.0, 0.5, 'real')
